# %%
import h5py
import warnings
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras.backend as K
import tensorflow as tf

from google.colab import drive
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
from keras.models import Model
from keras.layers import Input, Dense
from keras.initializers import glorot_uniform
from keras.optimizers import Adam

sns.set()
warnings.filterwarnings("ignore")
drive.mount('/content/drive/')
print (tf.test.gpu_device_name())
# Out:
# Using TensorFlow backend.
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /device:GPU:0

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# **Data Preview**

# %%
df_raw = pd.read_csv("/content/drive/My Drive/Colab/Research - Transactive Energy/Final Modified Data.csv")
df = df_raw.copy()

fig, ax = plt.subplots(1, 1)
ax2 = ax.twinx()

PV_plot = ax.plot(df.iloc[0:24, 0], 'ro-', label = "PV")
load_plot = ax.plot(df.iloc[0:24, 1], 'b*-', label = "Load")
price_plot = ax2.plot(df.iloc[0:24, 2], 'k.-', label = "RTP")

# Show all label in one box
plots = PV_plot + load_plot + price_plot
labels = [plot.get_label() for plot in plots]
ax.legend(plots, labels, loc = 0)

ax.set_xlabel("Hour")
ax.set_ylabel("Power (kW)")
ax2.set_ylabel("Price ($/ kWh)")

plt.show()

# %% [markdown]
# **Standardization**

# %%
# StandardScaler

# The mean is not shifted to zero-centered
sc_price = StandardScaler(with_mean = False)
price = sc_price.fit_transform(df.iloc[:, 2:].values)

sc_energy = StandardScaler(with_mean = False)
pv = sc_energy.fit_transform(df.iloc[:, 0:1].values)
load = sc_energy.transform(df.iloc[:, 1:2].values)

x = np.concatenate([pv, load, price], axis = -1)

# %%
fig, ax = plt.subplots(3, 2, figsize = (12, 12))

ax[0, 0].plot(x[:, 0])
ax[0, 0].set_xlabel("Hour")
ax[0, 0].set_ylabel("PV (kW)")

ax[0, 1].plot(x[0:24, 0])
ax[0, 1].set_xlabel("Hour")
ax[0, 1].set_ylabel("PV (pu)")

ax[1, 0].plot(x[:, 1])
ax[1, 0].set_xlabel("Hour")
ax[1, 0].set_ylabel("Load (kW)")

ax[1, 1].plot(x[0:24, 1])
ax[1, 1].set_xlabel("Hour")
ax[1, 1].set_ylabel("Load (pu)")

ax[2, 0].plot(x[:, 2])
ax[2, 0].set_xlabel("Hour")
ax[2, 0].set_ylabel("Price ($/kWh)")

ax[2, 1].plot(x[0:24, 2])
ax[2, 1].set_xlabel("Hour")
ax[2, 1].set_ylabel("Price (pu)")
plt.show()

# %% [markdown]
# # Value Based

# %% [markdown]
# **Deep Q-Network Model**

# %%
class DQNNet():
  
  def __init__(self, state_size, action_size, learning_rate):
    
    self.state_size = state_size
    self.action_size = action_size
    self.learning_rate = learning_rate
    self.model = self.create_model()
    
  def create_model(self):
    
    input = Input(shape = self.state_size)
    x = Dense(40, activation = "elu", 
              kernel_initializer = glorot_uniform(seed = 42))(input)
    x = Dense(160, activation = "elu",
              kernel_initializer = glorot_uniform(seed = 42))(x)
    output = Dense(self.action_size, activation = "linear", 
              kernel_initializer = glorot_uniform(seed = 42))(x)
    model = Model(inputs = [input], outputs = [output])
    model.compile(loss = "mse", optimizer = Adam(lr = self.learning_rate))
    model.summary()
    
    return model

# %% [markdown]
# **Memory Model**

# %%
# A tree based array containing priority of each experience for fast sampling

class SumTree():
  
  """
  __init__ - create data array storing experience and a tree based array storing priority
  add - store new experience in data array and update tree with new priority
  update - update tree and propagate the change through the tree
  get_leaf - find the final nodes with a given priority value
  """

  data_pointer = 0

  def __init__(self, capacity):
    
    """
    capacity - Number of final nodes containing experience
    data - array containing experience (with pointers to Python objects)
    tree - a tree shape array containing priority of each experience

     tree:
        0
       / \
      0   0
     / \ / \
    0  0 0  0 
    """
    self.capacity = capacity
    self.data = np.zeros(capacity, dtype = object)
    self.tree = np.zeros(2 * capacity - 1)

  def add(self, priority, data):
    
    # Start from first leaf node of the most bottom layer
    tree_index = self.data_pointer + self.capacity - 1

    self.data[self.data_pointer] = data # Update data frame
    self.update(tree_index, priority) # Update priority

    # Overwrite if exceed memory capacity
    self.data_pointer += 1
    if self.data_pointer >= self.capacity:  
      self.data_pointer = 0

  def update(self, tree_index, priority):

    # Change = new priority score - former priority score
    change = priority - self.tree[tree_index] 
    self.tree[tree_index] = priority

    # Propagate the change through tree
    while tree_index != 0: 
      tree_index = (tree_index - 1) // 2
      self.tree[tree_index] += change

  def get_leaf(self, v):

    parent_index = 0

    while True:
      left_child_index = 2 * parent_index + 1
      right_child_index = left_child_index + 1
      # Downward search, always search for a higher priority node till the last layer
      if left_child_index >= len(self.tree):
        leaf_index = parent_index
        break
      else: 
        if v <= self.tree[left_child_index]:
          parent_index = left_child_index
        else:
          v -= self.tree[left_child_index]
          parent_index = right_child_index

    data_index = leaf_index - self.capacity + 1
      
    # tree leaf index, priority, experience
    return leaf_index, self.tree[leaf_index], self.data[data_index]

# %%
class Memory():  # stored as (s, a, r, s_) in SumTree
    
  """
  
  __init__ - create SumTree memory
  store - assign priority to new experience and store with SumTree.add & SumTree.update
  sample - uniformly sample from the range between 0 and total priority and 
           retrieve the leaf index, priority and experience with SumTree.get_leaf
  batch_update - update the priority of experience after training with SumTree.update
  
  PER_e - Hyperparameter that avoid experiences having 0 probability of being taken
  PER_a - Hyperparameter that allows tradeoff between taking only experience with 
          high priority and sampling randomly (0 - pure uniform randomness, 1 -
          select experiences with the highest priority)
  PER_b - Importance-sampling, from initial value increasing to 1, control how much
          IS affect learning
          
  """
  
  PER_e = 0.01 
  PER_a = 0.6
  PER_b = 0.4
  PER_b_increment_per_sampling = 0.01
  absolute_error_upper = 1.  # Clipped abs error

  def __init__(self, capacity):
    
    self.tree = SumTree(capacity)

  def store(self, experience):
    
    # Find the max priority
    max_priority = np.max(self.tree.tree[-self.tree.capacity:])

    # If the max priority = 0, this experience will never have a chance to be selected
    # So a minimum priority is assigned
    if max_priority == 0:
      max_priority = self.absolute_error_upper

    self.tree.add(max_priority, experience)

  def sample(self, n):

    """
    First, to sample a minibatch of k size, the range [0, priority_total] is
    divided into k ranges. A value is uniformly sampled from each range. Search 
    in the sumtree, the experience where priority score correspond to sample 
    values are retrieved from. Calculate IS weights for each minibatch element
    """

    b_memory = []
    b_idx = np.empty((n, ))
    b_ISWeights =  np.empty((n, 1))

    priority_segment = self.tree.tree[0] / n   

    self.PER_b = np.min([1., self.PER_b + self.PER_b_increment_per_sampling])

    prob_min = np.min(self.tree.tree[-self.tree.capacity:]) / self.tree.tree[0]
    max_weight = (prob_min * n) ** (-self.PER_b)

    for i in range(n):
      a = priority_segment * i
      b = priority_segment * (i + 1)
      value = np.random.uniform(a, b)
      index, priority, data = self.tree.get_leaf(value)
      prob = priority / self.tree.tree[0]
      b_ISWeights[i, 0] = (prob * n) ** (-self.PER_b) / max_weight               
      b_idx[i]= index
      b_memory.append([data])

    return b_idx, b_memory, b_ISWeights

  def batch_update(self, tree_idx, abs_errors):
      
    # To avoid 0 probability
    abs_errors += self.PER_e 
    clipped_errors = np.minimum(abs_errors, self.absolute_error_upper)
    ps = np.power(clipped_errors, self.PER_a)

    for ti, p in zip(tree_idx, ps):
      self.tree.update(ti, p)

# %% [markdown]
# **Battery Model**

# %%
class Battery():
    
  def __init__(self, action_size, scaler_energy, scaler_price):
    
    """
    P_rated - charge/ discharge rate (kW)
    E_rated - rated capacity (kWh)
    C_E - energy capital cost ($/kWh)
    LC - life cycle
    eta - efficiency
    DOD - depth of discharge
    wear_cost - wear & operation cost ($/kWh/operation)
    wear_cost = (C_E * E_rated) / (eta * E_rated * LC * DOD)
    """ 
    self.P_rated = scaler_energy.transform(np.array([[1000]]))[0] # pu
    self.E_rated = scaler_energy.transform(np.array([[5000]]))[0] # pu 
    self.C_E = scaler_price.transform(np.array([[171]]))[0] # pu
    self.LC = 4996
    self.eta = 1.
    self.DOD = 1.
    self.wear_cost = self.C_E / self.eta / self.DOD / self.LC
    self.action_set = np.linspace(-1, 1, num = action_size, endpoint = True)
    self.initial_SOC = 0.
    
  def compute(self, state, action):
    
    current_pv = state[0]
    current_load = state[1]
    current_price = state[2]
    current_SOC = state[3]
    average_price = state[4]
    
    delta_SOC = self.action_set[action] * self.P_rated / self.E_rated
    
    if self.action_set[action] <= 0:
      next_SOC = np.maximum(0., current_SOC + delta_SOC)
      # Assign penalty if battery operates exceeding permissible limit
      if abs(delta_SOC) > current_SOC:
        penalty = 10
      else:
        penalty = 0
    else:
      next_SOC = np.minimum(1., current_SOC + delta_SOC)
      if abs(delta_SOC) > 1 - current_SOC:
        penalty = 10
      else:
        penalty = 0
        
    energy_gain = average_price * next_SOC * self.E_rated
    trading_cost = current_price * (current_load + (next_SOC - current_SOC) * self.E_rated)
    wear_cost = self.wear_cost * np.abs((next_SOC - current_SOC) * self.E_rated)
    
    # +ve - positive reward/ gain
    reward = energy_gain - trading_cost - wear_cost - penalty
    
    return next_SOC, reward

# %% [markdown]
# **Hyperparameters Setting**

# %%
# DQN hyperparameters
state_size = (5, )
action_size = 11
learning_rate = 0.001

# Training hyperparameters
batch_size = 64             

# Exploration hyperparameters for epsilon greedy strategy
explore_start = 1.0 # exploration probability at start
explore_stop = 0.01 # minimum exploration probability 
decay_rate = 0.0001 # exponential decay rate for exploration prob

# Q-learning hyperparameters
gamma = 0.95 # Discounting rate of future reward

# Memory hyperparameters
pretrain_length = 10000 # # of experiences stored in Memory during initialization
memory_size = 10000 # # of experiences Memory can keep

# %% [markdown]
# **Memory Initialization**

# %%
battery = Battery(action_size = action_size, 
                  scaler_energy = sc_energy, 
                  scaler_price = sc_price)

memory = Memory(memory_size)

np.random.seed(42)

# Memory initialization
SOC = np.array([battery.initial_SOC])
historical_price = np.zeros(24)
day = 0
hour = 0
done = False

for i in range(pretrain_length):
  
  # Keep track of the past 24 hours' electricity price
  historical_price[hour] = x[day * 24 + hour, 2]
  average_price = np.mean(np.array([price for price in historical_price if price != 0]))
  
  state = np.concatenate((x[day * 24 + hour, :], SOC, np.array([average_price])), axis = -1)
  action = np.random.randint(0, action_size)
  
  # Compute the reward and new state based on the selected action
  next_SOC, reward = battery.compute(state, action)
  
  # Store the experience in memory
  if hour < 23:
    hour += 1
    historical_price[hour] = x[day * 24 + hour, 2]
    average_price = np.mean(np.array([price for price in historical_price if price != 0]))
    next_state = np.concatenate((x[day * 24 + hour, :], next_SOC, np.array([average_price])), axis = -1)
  else:
    done = True
    day += 1
    hour = 0
    if day < len(x) / 24:
      historical_price[hour] = x[day * 24 + hour, 2]
      average_price = np.mean(np.array([price for price in historical_price if price != 0]))
      next_state = np.concatenate((x[day * 24 + hour, :], next_SOC, np.array([average_price])), axis = -1)
    else:
      break
      
  SOC = next_SOC
  experience = state, action, reward, next_state, done
  memory.store(experience)

# %% [markdown]
# **DQN Training**

# %%
DQN = DQNNet(state_size = state_size, 
             action_size = action_size, 
             learning_rate = learning_rate)

decay_step = 0 # Decay rate for ϵ-greedy policy
SOC = np.array([battery.initial_SOC])
day = 0
hour = 0
done = False
hour_rewards = []
day_mean_rewards = []

while day < len(x) / 24:

  # Keep track of the past 24 hours' electricity price
  historical_price[hour] = x[day * 24 + hour, 2]
  average_price = np.mean(np.array([price for price in historical_price if price != 0]))
  
  state = np.concatenate((x[day * 24 + hour, :], SOC, np.array([average_price])), axis = -1)

  # ϵ-greedy policy        
  exp_exp_tradeoff = np.random.rand()
  explore_probability = explore_stop + (explore_start - explore_stop) * np.exp(-decay_rate * decay_step)
  if (explore_probability > exp_exp_tradeoff):
    action = np.random.randint(0, action_size)
  else:
    action = np.argmax(DQN.model.predict(np.expand_dims(state, axis = 0)))

  # Compute the reward and new state based on the selected action
  next_SOC, reward = battery.compute(state, action)  

  hour_rewards.append(reward)
  
  # Store the experience in memory
  if hour < 23:
    hour += 1
    historical_price[hour] = x[day * 24 + hour, 2]
    average_price = np.mean(np.array([price for price in historical_price if price != 0]))
    next_state = np.concatenate((x[day * 24 + hour, :], next_SOC, np.array([average_price])), axis = -1)
  else:
    done = True
    day += 1
    hour = 0
    if day < len(x) / 24:
      historical_price[hour] = x[day * 24 + hour, 2]
      average_price = np.mean(np.array([price for price in historical_price if price != 0]))
      next_state = np.concatenate((x[day * 24 + hour, :], next_SOC, np.array([average_price])), axis = -1)
    else:
      break
    mean_reward = np.mean(hour_rewards)
    day_mean_rewards.append(mean_reward)
    hour_rewards = []
    print("Day: {}".format(day),
          "Mean reward: {:.2f}".format(mean_reward),
          "Training loss: {:.2f}".format(loss),
          "Explore P: {:.2f} \n".format(explore_probability))  
  
  SOC = next_SOC 
  experience = state, action, reward, next_state, done
  memory.store(experience)
  decay_step +=1
  
  # DQN training            
  tree_idx, batch, ISWeights_mb = memory.sample(batch_size) # Obtain random mini-batch from memory

  states_mb = np.array([each[0][0] for each in batch])
  actions_mb = np.array([each[0][1] for each in batch])
  rewards_mb = np.array([each[0][2] for each in batch]) 
  next_states_mb = np.array([each[0][3] for each in batch])
  dones_mb = np.array([each[0][4] for each in batch])

  targets_mb = DQN.model.predict(states_mb)

  # Update those targets at which actions are taken
  target_batch = []
  q_next_state = DQN.model.predict(next_states_mb)
  for i in range(0, len(batch)):  
    action = np.argmax(q_next_state[i])
    if dones_mb[i] == 1:
      target_batch.append(rewards_mb[i])
    else:
      target = rewards_mb[i] + gamma * q_next_state[i][action]
      target_batch.append(rewards_mb[i])

  # Replace the original with the updated targets
  one_hot = np.zeros((len(batch), action_size))
  one_hot[np.arange(len(batch)), actions_mb] = 1
  targets_mb = targets_mb.astype("float64")
  target_batch = np.array([each for each in target_batch]).astype("float64")
  np.place(targets_mb, one_hot > 0, target_batch)

  loss = DQN.model.train_on_batch(states_mb, targets_mb, sample_weight = ISWeights_mb.ravel())

  # Update priority
  absolute_errors = []
  predicts_mb = DQN.model.predict(states_mb)
  for i in range(0, len(batch)):
    absolute_errors.append(np.abs(predicts_mb[i][actions_mb[i]] - targets_mb[i][actions_mb[i]]))
  absolute_errors = np.array(absolute_errors)

  tree_idx = np.array([int(each) for each in tree_idx])
  memory.batch_update(tree_idx, absolute_errors)
  
  # Save model every 5 days
  if day % 5 == 0:
    DQN.model.save_weights("/content/drive/My Drive/Colab/Research - Transactive Energy/DQN.hdf5")
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 5)                 0
# _________________________________________________________________
# dense_16 (Dense)             (None, 40)                240
# _________________________________________________________________
# dense_17 (Dense)             (None, 160)               6560
# _________________________________________________________________
# dense_18 (Dense)             (None, 11)                1771
# =================================================================
# Total params: 8,571
# Trainable params: 8,571
# Non-trainable params: 0
# _________________________________________________________________
# Day: 1 Mean reward: -3.02 Training loss: 0.38 Explore P: 1.00
#
# Day: 2 Mean reward: -5.44 Training loss: 0.14 Explore P: 1.00
#
# Day: 3 Mean reward: -1.32 Training loss: 0.15 Explore P: 0.99
#
# Day: 4 Mean reward: -1.93 Training loss: 0.18 Explore P: 0.99
#
# Day: 5 Mean reward: 1.60 Training loss: 0.16 Explore P: 0.99
#
# Day: 6 Mean reward: -2.13 Training loss: 0.11 Explore P: 0.99
#
# Day: 7 Mean reward: -7.38 Training loss: 0.09 Explore P: 0.98
#
# Day: 8 Mean reward: -2.70 Training loss: 0.10 Explore P: 0.98
#
# Day: 9 Mean reward: -0.10 Training loss: 0.09 Explore P: 0.98
#
# Day: 10 Mean reward: -9.09 Training loss: 0.11 Explore P: 0.98
#
# Day: 11 Mean reward: -6.91 Training loss: 0.08 Explore P: 0.97
#
# Day: 12 Mean reward: 2.25 Training loss: 0.08 Explore P: 0.97
#
# Day: 13 Mean reward: -1.37 Training loss: 0.07 Explore P: 0.97
#
# Day: 14 Mean reward: -3.76 Training loss: 0.05 Explore P: 0.97
#
# Day: 15 Mean reward: 9.07 Training loss: 0.06 Explore P: 0.97
#
# Day: 55 Mean reward: 3.62 Training loss: 0.02 Explore P: 0.88
#
# Day: 56 Mean reward: 4.26 Training loss: 0.03 Explore P: 0.88
#
# Day: 57 Mean reward: 3.05 Training loss: 0.03 Explore P: 0.87
#
# Day: 58 Mean reward: 3.73 Training loss: 0.03 Explore P: 0.87
#
# Day: 59 Mean reward: 2.68 Training loss: 0.03 Explore P: 0.87
#
# Day: 60 Mean reward: -0.43 Training loss: 0.03 Explore P: 0.87
#
# Day: 61 Mean reward: -4.32 Training loss: 0.03 Explore P: 0.87
#
# Day: 62 Mean reward: -1.32 Training loss: 0.03 Explore P: 0.86
#
# Day: 63 Mean reward: -1.63 Training loss: 0.03 Explore P: 0.86
#
# Day: 64 Mean reward: -0.98 Training loss: 0.03 Explore P: 0.86
#
# Day: 65 Mean reward: -0.66 Training loss: 0.03 Explore P: 0.86
#
# Day: 66 Mean reward: -0.45 Training loss: 0.03 Explore P: 0.86
#
# Day: 67 Mean reward: -2.33 Training loss: 0.03 Explore P: 0.85
#
# Day: 68 Mean reward: -0.31 Training loss: 0.02 Explore P: 0.85
#
# Day: 69 Mean reward: -4.68 Training loss: 0.04 Explore P: 0.85
#
# Day: 70 Mean reward: 1.34 Training loss: 0.03 Explore P: 0.85
#
# Day: 71 Mean reward: 1.82 Training loss: 0.03 Explore P: 0.84
#
# Day: 72 Mean reward: -0.20 Training loss: 0.03 Explore P: 0.84
#
# Day: 73 Mean reward: -2.70 Training loss: 0.03 Explore P: 0.84
#
# Day: 74 Mean reward: -6.37 Training loss: 0.04 Explore P: 0.84
#
# Day: 75 Mean reward: -1.78 Training loss: 0.03 Explore P: 0.84
#
# Day: 76 Mean reward: 1.61 Training loss: 0.03 Explore P: 0.84
#
# Day: 77 Mean reward: 1.52 Training loss: 0.03 Explore P: 0.83
#
# Day: 78 Mean reward: 1.72 Training loss: 0.03 Explore P: 0.83
#
# Day: 79 Mean reward: 2.06 Training loss: 0.03 Explore P: 0.83
#
# Day: 80 Mean reward: 3.05 Training loss: 0.03 Explore P: 0.83
#
# Day: 81 Mean reward: 2.81 Training loss: 0.03 Explore P: 0.83
#
# Day: 82 Mean reward: -2.52 Training loss: 0.03 Explore P: 0.82
#
# Day: 83 Mean reward: -3.75 Training loss: 0.03 Explore P: 0.82
#
# Day: 84 Mean reward: 0.95 Training loss: 0.02 Explore P: 0.82
#
# Day: 85 Mean reward: -0.55 Training loss: 0.03 Explore P: 0.82
#
# Day: 86 Mean reward: -0.15 Training loss: 0.03 Explore P: 0.82
#
# Day: 87 Mean reward: 2.14 Training loss: 0.02 Explore P: 0.81
#
# Day: 88 Mean reward: 3.67 Training loss: 0.03 Explore P: 0.81
#
# Day: 89 Mean reward: 1.26 Training loss: 0.04 Explore P: 0.81
#
# Day: 90 Mean reward: 3.63 Training loss: 0.03 Explore P: 0.81
#
# Day: 91 Mean reward: 2.28 Training loss: 0.03 Explore P: 0.81
#
# Day: 92 Mean reward: 2.15 Training loss: 0.02 Explore P: 0.80
#
# Day: 93 Mean reward: 2.45 Training loss: 0.02 Explore P: 0.80
#
# Day: 94 Mean reward: 1.68 Training loss: 0.02 Explore P: 0.80
#
# Day: 95 Mean reward: -4.71 Training loss: 0.03 Explore P: 0.80
#
# Day: 96 Mean reward: 3.85 Training loss: 0.03 Explore P: 0.80
#
# Day: 97 Mean reward: -0.15 Training loss: 0.04 Explore P: 0.79
#
# Day: 98 Mean reward: -0.63 Training loss: 0.02 Explore P: 0.79
#
# Day: 99 Mean reward: 2.37 Training loss: 0.03 Explore P: 0.79
#
# Day: 100 Mean reward: 1.13 Training loss: 0.03 Explore P: 0.79
#
# Day: 101 Mean reward: 1.53 Training loss: 0.02 Explore P: 0.79
#
# Day: 102 Mean reward: 3.98 Training loss: 0.03 Explore P: 0.79
#
# Day: 103 Mean reward: 3.54 Training loss: 0.03 Explore P: 0.78
#
# Day: 104 Mean reward: 2.32 Training loss: 0.02 Explore P: 0.78
#
# Day: 105 Mean reward: 2.65 Training loss: 0.01 Explore P: 0.78
#
# Day: 106 Mean reward: 2.43 Training loss: 0.03 Explore P: 0.78
#
# Day: 107 Mean reward: 3.60 Training loss: 0.03 Explore P: 0.78
#
# Day: 108 Mean reward: 2.40 Training loss: 0.02 Explore P: 0.77
#
# Day: 109 Mean reward: 3.22 Training loss: 0.02 Explore P: 0.77
#
# Day: 110 Mean reward: 2.22 Training loss: 0.02 Explore P: 0.77
#
# Day: 111 Mean reward: 1.15 Training loss: 0.02 Explore P: 0.77
#
# Day: 112 Mean reward: 3.33 Training loss: 0.02 Explore P: 0.77
#
# Day: 113 Mean reward: 4.37 Training loss: 0.02 Explore P: 0.76
#
# Day: 114 Mean reward: -0.56 Training loss: 0.02 Explore P: 0.76
#
# Day: 115 Mean reward: 2.73 Training loss: 0.03 Explore P: 0.76
#
# Day: 116 Mean reward: 4.08 Training loss: 0.03 Explore P: 0.76
#
# Day: 117 Mean reward: -1.15 Training loss: 0.02 Explore P: 0.76
#
# Day: 118 Mean reward: 0.53 Training loss: 0.03 Explore P: 0.76
#
# Day: 119 Mean reward: 0.79 Training loss: 0.02 Explore P: 0.75
#
# Day: 120 Mean reward: 3.24 Training loss: 0.02 Explore P: 0.75
#
# Day: 121 Mean reward: 1.65 Training loss: 0.02 Explore P: 0.75
#
# Day: 122 Mean reward: 0.53 Training loss: 0.02 Explore P: 0.75
#
# Day: 123 Mean reward: -0.86 Training loss: 0.02 Explore P: 0.75
#
# Day: 124 Mean reward: -0.60 Training loss: 0.02 Explore P: 0.75
#
# Day: 125 Mean reward: -1.90 Training loss: 0.02 Explore P: 0.74
#
# Day: 126 Mean reward: 0.95 Training loss: 0.02 Explore P: 0.74
#
# Day: 127 Mean reward: -0.89 Training loss: 0.03 Explore P: 0.74
#
# Day: 128 Mean reward: 1.27 Training loss: 0.02 Explore P: 0.74
#
# Day: 129 Mean reward: -1.98 Training loss: 0.02 Explore P: 0.74
#
# Day: 130 Mean reward: -0.28 Training loss: 0.02 Explore P: 0.73
#
# Day: 131 Mean reward: 3.68 Training loss: 0.01 Explore P: 0.73
#
#
# Day: 249 Mean reward: 1.48 Training loss: 0.02 Explore P: 0.55
#
# Day: 250 Mean reward: -1.81 Training loss: 0.01 Explore P: 0.55
#
# Day: 251 Mean reward: 0.49 Training loss: 0.02 Explore P: 0.55
#
# Day: 252 Mean reward: -0.61 Training loss: 0.02 Explore P: 0.55
#
# Day: 253 Mean reward: -0.54 Training loss: 0.02 Explore P: 0.55
#
# Day: 254 Mean reward: 3.68 Training loss: 0.01 Explore P: 0.55
#
# Day: 255 Mean reward: 0.05 Training loss: 0.02 Explore P: 0.55
#
# Day: 256 Mean reward: -0.50 Training loss: 0.01 Explore P: 0.55
#
# Day: 257 Mean reward: 1.41 Training loss: 0.01 Explore P: 0.54
#
# Day: 258 Mean reward: 2.18 Training loss: 0.01 Explore P: 0.54
#
# Day: 259 Mean reward: 3.48 Training loss: 0.02 Explore P: 0.54
#
# Day: 260 Mean reward: 3.48 Training loss: 0.02 Explore P: 0.54
#
# Day: 261 Mean reward: 2.46 Training loss: 0.02 Explore P: 0.54
#
# Day: 262 Mean reward: 3.27 Training loss: 0.01 Explore P: 0.54
#
# Day: 263 Mean reward: 2.90 Training loss: 0.02 Explore P: 0.54
#
# Day: 264 Mean reward: 3.05 Training loss: 0.02 Explore P: 0.54
#
# Day: 265 Mean reward: 3.37 Training loss: 0.01 Explore P: 0.53
#
# Day: 266 Mean reward: 2.58 Training loss: 0.02 Explore P: 0.53
#
# Day: 267 Mean reward: 2.68 Training loss: 0.02 Explore P: 0.53
#
# Day: 268 Mean reward: 0.44 Training loss: 0.02 Explore P: 0.53
#
# Day: 269 Mean reward: -5.14 Training loss: 0.02 Explore P: 0.53
#
# Day: 270 Mean reward: 4.60 Training loss: 0.01 Explore P: 0.53
#
# Day: 271 Mean reward: 3.56 Training loss: 0.02 Explore P: 0.53
#
# Day: 272 Mean reward: 1.76 Training loss: 0.02 Explore P: 0.53
#
# Day: 273 Mean reward: 4.35 Training loss: 0.02 Explore P: 0.52
#
# Day: 274 Mean reward: 3.15 Training loss: 0.02 Explore P: 0.52
#
# Day: 275 Mean reward: 2.04 Training loss: 0.01 Explore P: 0.52
#
# Day: 276 Mean reward: 3.71 Training loss: 0.02 Explore P: 0.52
#
# Day: 277 Mean reward: -0.17 Training loss: 0.01 Explore P: 0.52
#
# Day: 278 Mean reward: 0.66 Training loss: 0.02 Explore P: 0.52
#
# Day: 279 Mean reward: 1.01 Training loss: 0.03 Explore P: 0.52
#
# Day: 280 Mean reward: 0.18 Training loss: 0.01 Explore P: 0.52
#
# Day: 281 Mean reward: 0.47 Training loss: 0.02 Explore P: 0.51
#
# Day: 282 Mean reward: 3.05 Training loss: 0.01 Explore P: 0.51
#
# Day: 283 Mean reward: -0.28 Training loss: 0.02 Explore P: 0.51
#
# Day: 284 Mean reward: 2.49 Training loss: 0.02 Explore P: 0.51
#
# Day: 285 Mean reward: 2.52 Training loss: 0.02 Explore P: 0.51
#
# Day: 286 Mean reward: 2.98 Training loss: 0.01 Explore P: 0.51
#
# Day: 287 Mean reward: 3.14 Training loss: 0.01 Explore P: 0.51
# Day: 905 Mean reward: 0.34 Training loss: 0.01 Explore P: 0.12
#
# Day: 906 Mean reward: -2.19 Training loss: 0.00 Explore P: 0.12
#
# Day: 907 Mean reward: 1.60 Training loss: 0.00 Explore P: 0.12
#
# Day: 908 Mean reward: 1.21 Training loss: 0.01 Explore P: 0.12
#
# Day: 909 Mean reward: 3.14 Training loss: 0.01 Explore P: 0.12
#
# Day: 910 Mean reward: 2.96 Training loss: 0.00 Explore P: 0.12
#
# Day: 911 Mean reward: 2.57 Training loss: 0.01 Explore P: 0.12
#
# Day: 912 Mean reward: 0.03 Training loss: 0.01 Explore P: 0.12
#
# Day: 913 Mean reward: -1.19 Training loss: 0.01 Explore P: 0.12
#
# Day: 914 Mean reward: -2.26 Training loss: 0.00 Explore P: 0.12
#
# Day: 915 Mean reward: 0.52 Training loss: 0.01 Explore P: 0.12
#
# Day: 916 Mean reward: 1.29 Training loss: 0.01 Explore P: 0.12
#
# Day: 917 Mean reward: 0.28 Training loss: 0.00 Explore P: 0.12
#
# Day: 918 Mean reward: 1.09 Training loss: 0.01 Explore P: 0.12
#
# Day: 919 Mean reward: 0.10 Training loss: 0.00 Explore P: 0.12
#
# Day: 920 Mean reward: -0.17 Training loss: 0.00 Explore P: 0.12
#
# Day: 921 Mean reward: 3.98 Training loss: 0.00 Explore P: 0.12
#
# Day: 922 Mean reward: 2.91 Training loss: 0.01 Explore P: 0.12
#
# Day: 923 Mean reward: 3.75 Training loss: 0.00 Explore P: 0.12
#
# Day: 924 Mean reward: 3.32 Training loss: 0.00 Explore P: 0.12
#
# Day: 925 Mean reward: 2.21 Training loss: 0.01 Explore P: 0.12
#
# Day: 926 Mean reward: 0.22 Training loss: 0.01 Explore P: 0.12
#
# Day: 927 Mean reward: -2.27 Training loss: 0.01 Explore P: 0.12
#
# Day: 928 Mean reward: 0.30 Training loss: 0.00 Explore P: 0.12
#
# Day: 929 Mean reward: -2.18 Training loss: 0.00 Explore P: 0.12
#
# Day: 930 Mean reward: -0.14 Training loss: 0.00 Explore P: 0.12
#
# Day: 931 Mean reward: 4.17 Training loss: 0.01 Explore P: 0.12
#
# Day: 932 Mean reward: 9.91 Training loss: 0.01 Explore P: 0.12
#
# Day: 933 Mean reward: 5.98 Training loss: 0.00 Explore P: 0.12
#
# Day: 934 Mean reward: -0.55 Training loss: 0.01 Explore P: 0.12
#
# Day: 935 Mean reward: 0.81 Training loss: 0.00 Explore P: 0.11
#
# Day: 936 Mean reward: 1.56 Training loss: 0.01 Explore P: 0.11
#
# Day: 937 Mean reward: 1.72 Training loss: 0.01 Explore P: 0.11
#
# Day: 938 Mean reward: 1.54 Training loss: 0.00 Explore P: 0.11
#
# Day: 939 Mean reward: 1.14 Training loss: 0.00 Explore P: 0.11
#
# Day: 940 Mean reward: 1.26 Training loss: 0.00 Explore P: 0.11
#
# Day: 941 Mean reward: -1.35 Training loss: 0.01 Explore P: 0.11
#
# Day: 942 Mean reward: 1.73 Training loss: 0.01 Explore P: 0.11
#
# Day: 943 Mean reward: 1.46 Training loss: 0.01 Explore P: 0.11
#
# Day: 944 Mean reward: 0.48 Training loss: 0.00 Explore P: 0.11
#
# Day: 945 Mean reward: 0.96 Training loss: 0.00 Explore P: 0.11
#
# Day: 946 Mean reward: 2.11 Training loss: 0.00 Explore P: 0.11
#
# Day: 947 Mean reward: 0.90 Training loss: 0.00 Explore P: 0.11
#
# Day: 948 Mean reward: -0.03 Training loss: 0.00 Explore P: 0.11
#
# Day: 949 Mean reward: 0.99 Training loss: 0.00 Explore P: 0.11
#
# Day: 950 Mean reward: -0.39 Training loss: 0.01 Explore P: 0.11
#
# Day: 951 Mean reward: -0.26 Training loss: 0.01 Explore P: 0.11
#
# Day: 952 Mean reward: -0.72 Training loss: 0.01 Explore P: 0.11
#
# Day: 953 Mean reward: 1.52 Training loss: 0.00 Explore P: 0.11
#
# Day: 954 Mean reward: 1.51 Training loss: 0.00 Explore P: 0.11
#
# Day: 955 Mean reward: -1.48 Training loss: 0.01 Explore P: 0.11
#
# Day: 956 Mean reward: 1.58 Training loss: 0.01 Explore P: 0.11
#
# Day: 957 Mean reward: 3.26 Training loss: 0.01 Explore P: 0.11
#
# Day: 958 Mean reward: 1.67 Training loss: 0.00 Explore P: 0.11
#
# Day: 959 Mean reward: 1.17 Training loss: 0.01 Explore P: 0.11
#
# Day: 960 Mean reward: 2.18 Training loss: 0.01 Explore P: 0.11
#
# Day: 961 Mean reward: 1.05 Training loss: 0.01 Explore P: 0.11
#
# Day: 962 Mean reward: -1.48 Training loss: 0.01 Explore P: 0.11
#
# Day: 963 Mean reward: 1.83 Training loss: 0.00 Explore P: 0.11
#
# Day: 964 Mean reward: 1.31 Training loss: 0.01 Explore P: 0.11
#
# Day: 965 Mean reward: 1.38 Training loss: 0.00 Explore P: 0.11
#
# Day: 966 Mean reward: 4.36 Training loss: 0.00 Explore P: 0.11
#
# Day: 967 Mean reward: 3.93 Training loss: 0.00 Explore P: 0.11
#
# Day: 968 Mean reward: 1.04 Training loss: 0.01 Explore P: 0.11
#
# Day: 969 Mean reward: -0.28 Training loss: 0.01 Explore P: 0.11
#
# Day: 970 Mean reward: 1.73 Training loss: 0.00 Explore P: 0.11
#
# Day: 971 Mean reward: 0.87 Training loss: 0.01 Explore P: 0.11
#
# Day: 972 Mean reward: 2.03 Training loss: 0.01 Explore P: 0.11
#
# Day: 973 Mean reward: 1.67 Training loss: 0.01 Explore P: 0.11
#
# Day: 974 Mean reward: 1.14 Training loss: 0.01 Explore P: 0.11
#
# Day: 975 Mean reward: -0.66 Training loss: 0.01 Explore P: 0.11
#
# Day: 976 Mean reward: 0.92 Training loss: 0.00 Explore P: 0.11
#
# Day: 977 Mean reward: 0.36 Training loss: 0.00 Explore P: 0.10
#
# Day: 978 Mean reward: 2.56 Training loss: 0.00 Explore P: 0.10
#
# Day: 979 Mean reward: 1.53 Training loss: 0.00 Explore P: 0.10
#
# Day: 980 Mean reward: 2.28 Training loss: 0.00 Explore P: 0.10
#
# Day: 981 Mean reward: 0.95 Training loss: 0.00 Explore P: 0.10
#
# Day: 982 Mean reward: 1.22 Training loss: 0.00 Explore P: 0.10
#
# Day: 983 Mean reward: 1.05 Training loss: 0.01 Explore P: 0.10
#
# Day: 984 Mean reward: -0.92 Training loss: 0.01 Explore P: 0.10
#
# Day: 985 Mean reward: -2.72 Training loss: 0.00 Explore P: 0.10
#
# Day: 986 Mean reward: 4.51 Training loss: 0.00 Explore P: 0.10
#
# Day: 987 Mean reward: 8.32 Training loss: 0.00 Explore P: 0.10
#
# Day: 988 Mean reward: 2.78 Training loss: 0.01 Explore P: 0.10
#
# Day: 989 Mean reward: 1.08 Training loss: 0.00 Explore P: 0.10
#
# Day: 990 Mean reward: -2.50 Training loss: 0.00 Explore P: 0.10
#
# Day: 991 Mean reward: 2.42 Training loss: 0.00 Explore P: 0.10
#
# Day: 992 Mean reward: 1.12 Training loss: 0.01 Explore P: 0.10
#
# Day: 993 Mean reward: 1.56 Training loss: 0.00 Explore P: 0.10
#
# Day: 994 Mean reward: 0.62 Training loss: 0.00 Explore P: 0.10
#
# Day: 995 Mean reward: 1.65 Training loss: 0.00 Explore P: 0.10
#
# Day: 996 Mean reward: 1.79 Training loss: 0.00 Explore P: 0.10
#
# Day: 997 Mean reward: 1.10 Training loss: 0.01 Explore P: 0.10
#
# Day: 998 Mean reward: 1.05 Training loss: 0.00 Explore P: 0.10
#
# Day: 999 Mean reward: 1.11 Training loss: 0.00 Explore P: 0.10
#
# Day: 1000 Mean reward: 0.84 Training loss: 0.00 Explore P: 0.10
#
# Day: 1001 Mean reward: 0.95 Training loss: 0.01 Explore P: 0.10
#
# Day: 1002 Mean reward: 0.97 Training loss: 0.00 Explore P: 0.10
#
# Day: 1003 Mean reward: 2.05 Training loss: 0.01 Explore P: 0.10
#
# Day: 1004 Mean reward: -0.51 Training loss: 0.01 Explore P: 0.10
#
# Day: 1005 Mean reward: 2.15 Training loss: 0.00 Explore P: 0.10
#
# Day: 1006 Mean reward: 0.92 Training loss: 0.00 Explore P: 0.10
#
# Day: 1007 Mean reward: 0.65 Training loss: 0.00 Explore P: 0.10
#
# Day: 1008 Mean reward: 0.94 Training loss: 0.00 Explore P: 0.10
#
# Day: 1009 Mean reward: 2.01 Training loss: 0.00 Explore P: 0.10
#
# Day: 1010 Mean reward: 1.19 Training loss: 0.01 Explore P: 0.10
#
# Day: 1011 Mean reward: -0.82 Training loss: 0.00 Explore P: 0.10
#
# Day: 1012 Mean reward: 3.23 Training loss: 0.00 Explore P: 0.10
#
# Day: 1013 Mean reward: 2.35 Training loss: 0.00 Explore P: 0.10
#
# Day: 1014 Mean reward: 1.32 Training loss: 0.01 Explore P: 0.10
#
# Day: 1015 Mean reward: 0.50 Training loss: 0.01 Explore P: 0.10
#
# Day: 1016 Mean reward: -0.93 Training loss: 0.01 Explore P: 0.10
#
# Day: 1017 Mean reward: 1.60 Training loss: 0.00 Explore P: 0.10
#
# Day: 1018 Mean reward: -0.36 Training loss: 0.00 Explore P: 0.10
#
# Day: 1019 Mean reward: 2.83 Training loss: 0.00 Explore P: 0.10
#
# Day: 1020 Mean reward: -0.36 Training loss: 0.00 Explore P: 0.10
#
# Day: 1021 Mean reward: 0.73 Training loss: 0.01 Explore P: 0.10
#
# Day: 1022 Mean reward: 0.10 Training loss: 0.01 Explore P: 0.10
#
# Day: 1023 Mean reward: 4.00 Training loss: 0.01 Explore P: 0.09
#
# Day: 1024 Mean reward: 3.09 Training loss: 0.01 Explore P: 0.09
#
# Day: 1025 Mean reward: -1.67 Training loss: 0.01 Explore P: 0.09
#
# Day: 1026 Mean reward: 0.09 Training loss: 0.01 Explore P: 0.09
#
# Day: 1027 Mean reward: -0.83 Training loss: 0.00 Explore P: 0.09
#
# Day: 1028 Mean reward: 0.94 Training loss: 0.00 Explore P: 0.09
#
# Day: 1029 Mean reward: 0.37 Training loss: 0.00 Explore P: 0.09
#
# Day: 1030 Mean reward: 3.27 Training loss: 0.01 Explore P: 0.09
#
# Day: 1031 Mean reward: 2.88 Training loss: 0.00 Explore P: 0.09
#
# Day: 1032 Mean reward: -0.77 Training loss: 0.00 Explore P: 0.09
#
# Day: 1033 Mean reward: 1.36 Training loss: 0.00 Explore P: 0.09
#
# Day: 1034 Mean reward: 2.07 Training loss: 0.00 Explore P: 0.09
#
# Day: 1035 Mean reward: 0.47 Training loss: 0.00 Explore P: 0.09
#
# Day: 1036 Mean reward: 0.72 Training loss: 0.00 Explore P: 0.09
#
# Day: 1037 Mean reward: 3.80 Training loss: 0.01 Explore P: 0.09
#
# Day: 1038 Mean reward: 1.53 Training loss: 0.00 Explore P: 0.09
#
# Day: 1039 Mean reward: -2.50 Training loss: 0.00 Explore P: 0.09
#
# Day: 1040 Mean reward: 3.24 Training loss: 0.00 Explore P: 0.09
#
# Day: 1041 Mean reward: 3.04 Training loss: 0.00 Explore P: 0.09
#
# Day: 1042 Mean reward: 2.98 Training loss: 0.00 Explore P: 0.09
#
# Day: 1043 Mean reward: 0.92 Training loss: 0.00 Explore P: 0.09
#
# Day: 1044 Mean reward: 3.51 Training loss: 0.02 Explore P: 0.09
#
# Day: 1045 Mean reward: 3.37 Training loss: 0.00 Explore P: 0.09
#
# Day: 1046 Mean reward: -1.75 Training loss: 0.00 Explore P: 0.09
#
# Day: 1047 Mean reward: 1.48 Training loss: 0.01 Explore P: 0.09
#
# Day: 1048 Mean reward: 2.05 Training loss: 0.01 Explore P: 0.09
#
# Day: 1049 Mean reward: 1.54 Training loss: 0.01 Explore P: 0.09
#
# Day: 1050 Mean reward: 2.20 Training loss: 0.01 Explore P: 0.09
#
# Day: 1051 Mean reward: 2.95 Training loss: 0.00 Explore P: 0.09
#
# Day: 1052 Mean reward: 1.70 Training loss: 0.00 Explore P: 0.09
#
# Day: 1053 Mean reward: -0.56 Training loss: 0.01 Explore P: 0.09
#
# Day: 1054 Mean reward: -0.92 Training loss: 0.01 Explore P: 0.09
#
# Day: 1055 Mean reward: -0.72 Training loss: 0.00 Explore P: 0.09
#
# Day: 1056 Mean reward: 3.59 Training loss: 0.00 Explore P: 0.09
#
# Day: 1057 Mean reward: 2.38 Training loss: 0.00 Explore P: 0.09
#
# Day: 1058 Mean reward: 2.49 Training loss: 0.01 Explore P: 0.09
#
# Day: 1059 Mean reward: -3.65 Training loss: 0.00 Explore P: 0.09
#
# Day: 1060 Mean reward: -1.45 Training loss: 0.00 Explore P: 0.09
#
# Day: 1061 Mean reward: 5.72 Training loss: 0.01 Explore P: 0.09
#
# Day: 1062 Mean reward: 5.23 Training loss: 0.00 Explore P: 0.09
#
# Day: 1063 Mean reward: 5.43 Training loss: 0.01 Explore P: 0.09
#
# Day: 1064 Mean reward: -1.13 Training loss: 0.01 Explore P: 0.09
#
# Day: 1065 Mean reward: 2.18 Training loss: 0.01 Explore P: 0.09
#
# Day: 1066 Mean reward: 2.96 Training loss: 0.00 Explore P: 0.09
#
# Day: 1067 Mean reward: 0.48 Training loss: 0.01 Explore P: 0.09
#
# Day: 1068 Mean reward: 3.69 Training loss: 0.01 Explore P: 0.09
#
# Day: 1069 Mean reward: 3.37 Training loss: 0.00 Explore P: 0.09
#
# Day: 1070 Mean reward: 2.47 Training loss: 0.00 Explore P: 0.09
#
# Day: 1071 Mean reward: 0.74 Training loss: 0.01 Explore P: 0.09
#
# Day: 1072 Mean reward: 1.88 Training loss: 0.00 Explore P: 0.09
#
# Day: 1073 Mean reward: 1.43 Training loss: 0.00 Explore P: 0.09
#
# Day: 1074 Mean reward: -0.26 Training loss: 0.00 Explore P: 0.09
#
# Day: 1075 Mean reward: 0.43 Training loss: 0.01 Explore P: 0.09
#
# Day: 1076 Mean reward: -3.87 Training loss: 0.00 Explore P: 0.08
#
# Day: 1077 Mean reward: -9.98 Training loss: 0.00 Explore P: 0.08
#
# Day: 1078 Mean reward: -1.65 Training loss: 0.01 Explore P: 0.08
#
# Day: 1079 Mean reward: 10.57 Training loss: 0.01 Explore P: 0.08
#
# Day: 1080 Mean reward: 5.63 Training loss: 0.01 Explore P: 0.08

# %% [markdown]
# **Testing**

# %%
DQN.model.load_weights("/content/drive/My Drive/Colab/Research - Transactive Energy/DQN.hdf5")

SOC = np.array([battery.initial_SOC])
historical_price = np.zeros(24)
day = 0
hour = 0
done = False
SOC_list = []
action_list = []
reward_list = []
av_price_list = []

while day < len(x) / 24:
  
  historical_price[hour] = x[day * 24 + hour, 2]
  average_price = np.mean(np.array([price for price in historical_price if price != 0]))
  
  state = np.concatenate((x[day * 24 + hour, :], SOC, np.array([average_price])), axis = -1)
  action = np.argmax(DQN.model.predict(np.expand_dims(state, axis = 0)))
  
  next_SOC, reward = battery.compute(state, action)

  SOC = next_SOC
  SOC_list.append(SOC)
  reward_list.append(reward)
  action_list.append(action)
  av_price_list.append(average_price)  
  
  if hour < 23:
    hour += 1
    historical_price[hour] = x[day * 24 + hour, 2]
    average_price = np.mean(np.array([price for price in historical_price if price != 0]))
    next_state = np.concatenate((x[day * 24 + hour, :], next_SOC, np.array([average_price])), axis = -1)
  else:
    done = True
    day += 1
    hour = 0
    if day < len(x) / 24:
      historical_price[hour] = x[day * 24 + hour, 2]
      average_price = np.mean(np.array([price for price in historical_price if price != 0]))
      next_state = np.concatenate((x[day * 24 + hour, :], next_SOC, np.array([average_price])), axis = -1)
    else:
      break
  
print (np.mean(reward_list))
# Out:
# 2.3182068309614405

# %%
# First 10 days

i = 10

plt.figure(figsize = (20,5))
plt.step(range(0, 24 * i), SOC_list[0:24 * i], "ro-", label = "SOC")
plt.step(range(0, 24 * i), av_price_list[0:24 * i], label = "av_price")
plt.step(range(0, 24 * i), x[0:24 * i, 2], "bs", label = "price")
plt.bar(range(0, 24 * i), battery.action_set[action_list[0:24 * i]], 
        facecolor = "w", edgecolor = "k", label = "action")
plt.ylabel("SOC/ Normalized Price")
plt.xlabel("Hour")
plt.legend()
plt.show()

# %%
# Second last ten days

i = 10

plt.figure(figsize = (20,5))
plt.step(range(0, 24 * i), SOC_list[-24 * i * 2:-24 * i], "ro-", label = "SOC")
plt.step(range(0, 24 * i), av_price_list[-24 * i * 2:-24 * i], label = "av_price")
plt.step(range(0, 24 * i), x[-24 * i * 2:-24 * i, 2], "bs", label = "price")
plt.bar(range(0, 24 * i), battery.action_set[action_list[-24 * i * 2:-24 * i]], 
        facecolor = "w", edgecolor = "k", label = "action")
plt.ylabel("SOC/ Normalized Price")
plt.xlabel("Hour")
plt.legend()
plt.show()

# %%
# Last ten days

i = 10

plt.figure(figsize = (20,5))
plt.step(range(0, 24 * i), SOC_list[-24 * i:], "ro-", label = "SOC")
plt.step(range(0, 24 * i), av_price_list[-24 * i:], label = "av_price")
plt.step(range(0, 24 * i), x[-24 * i:, 2], "bs", label = "price")
plt.bar(range(0, 24 * i), battery.action_set[action_list[-24 * i:]], 
        facecolor = "w", edgecolor = "k", label = "action")
plt.ylabel("SOC/ Normalized Price")
plt.xlabel("Hour")
plt.legend()
plt.show()

# %%
"""
trading_cost - cost buying/ selling from/ to grid
operation_cost - wear cost of battery resulting from operation
"""

# Without ESS
trading_cost_WOESS = -sc_price.inverse_transform(x[:,2:]) \
                     * sc_energy.inverse_transform(x[:,1:2])
total_cost_WOESS = trading_cost_WOESS

# With ESS
trading_cost = -sc_price.inverse_transform(x[:,2:]) \
               * sc_energy.inverse_transform((x[:,1:2] \
                                              + np.expand_dims((battery.action_set[action_list] \
                                                                * battery.P_rated), axis = -1)))
operation_cost = -sc_price.inverse_transform(battery.wear_cost) \
                 * sc_energy.inverse_transform(np.abs(np.expand_dims((battery.action_set[action_list] \
                                                                      * battery.P_rated), axis = -1)))
total_cost = trading_cost + operation_cost

print ("Cost without ESS: {:0.2f}".format(np.sum(total_cost_WOESS)))
print ("Cost with ESS: {:0.2f}".format(np.sum(total_cost)))
print ("Net benefit: {:0.2f}".format(np.sum(total_cost) - np.sum(total_cost_WOESS)))
print ("Daily mean cost without ESS: {:0.2f}".format(np.sum(total_cost_WOESS) / (len(x) / 24 )))
print ("Daily mean cost with ESS: {:0.2f}".format(np.sum(total_cost) / (len(x) / 24 )))
print ("Daily net benefit: {:0.2f}".format((np.sum(total_cost) - np.sum(total_cost_WOESS)) / (len(x) / 24 )))
# Out:
# Cost without ESS: -21652404.58
# Cost with ESS: -21037072.08
# Net benefit: 615332.50
# Daily mean cost without ESS: -20029.98
# Daily mean cost with ESS: -19460.75
# Daily net benefit: 569.23
